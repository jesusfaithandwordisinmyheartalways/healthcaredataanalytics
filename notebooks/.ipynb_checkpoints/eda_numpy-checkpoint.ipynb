# %%
from openpyxl import load_workbook
import numpy as np

# Load cleaned Excel file
wb = load_workbook('../data/healthcare_data.xlsx')
sheet = wb.active

# Convert sheet to NumPy array (skip header)
data = np.array([[cell.value for cell in row] for row in sheet.iter_rows(min_row=2)])

# Billing amounts (column 6)
billing = data[:, 6].astype(float)

# Basic stats
print("Total Billing:", np.sum(billing))
print("Average Billing:", np.mean(billing))
print("Max Billing:", np.max(billing))

# Visits per Department (column 5)
departments = data[:, 5]
unique_departments, counts = np.unique(departments, return_counts=True)
for dept, count in zip(unique_departments, counts):
    print(f"{dept}: {count} visits")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import numpy as np
#       4 # Load cleaned Excel file
# ----> 5 wb = load_workbook('../data/healthcare_data_cleaned.xlsx')
#       6 sheet = wb.active
#       8 # Convert sheet to NumPy array (skip header)
#
# File ~/Data Analytics Healthcare Practice/venv/lib/python3.13/site-packages/openpyxl/reader/excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     317                   data_only=False, keep_links=True, rich_text=False):
#     318     """Open the given filename and return the workbook
#     319
#     320     :param filename: the path to open or a file-like object
#    (...)    344
#     345     """
# --> 346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
#     348     reader.read()
#     349     return reader.wb
#
# File ~/Data Analytics Healthcare Practice/venv/lib/python3.13/site-packages/openpyxl/reader/excel.py:123, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121 def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122              data_only=False, keep_links=True, rich_text=False):
# --> 123     self.archive = _validate_archive(fn)
#     124     self.valid_files = self.archive.namelist()
#     125     self.read_only = read_only
#
# File ~/Data Analytics Healthcare Practice/venv/lib/python3.13/site-packages/openpyxl/reader/excel.py:95, in _validate_archive(filename)
#      88             msg = ('openpyxl does not support %s file format, '
#      89                    'please check you can open '
#      90                    'it with Excel first. '
#      91                    'Supported formats are: %s') % (file_format,
#      92                                                    ','.join(SUPPORTED_FORMATS))
#      93         raise InvalidFileException(msg)
# ---> 95 archive = ZipFile(filename, 'r')
#      96 return archive
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/zipfile/__init__.py:1362, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1360 while True:
#    1361     try:
# -> 1362         self.fp = io.open(file, filemode)
#    1363     except OSError:
#    1364         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/healthcare_data_cleaned.xlsx'
